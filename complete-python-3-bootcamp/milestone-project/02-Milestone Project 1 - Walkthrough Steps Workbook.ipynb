# %% [markdown]
# # Milestone Project 1: Walkthrough Steps Workbook
#
# Below is a set of steps for you to follow to try to create the Tic Tac Toe Milestone Project game!

# %% [markdown]
# #### Some suggested tools before you get started:
# To take input from a user:
#
#     player1 = input("Please pick a marker 'X' or 'O'")
#
# Note that input() takes in a string. If you need an integer value, use
#
#     position = int(input('Please enter a number'))
#
# <br>To clear the screen between moves:
#
#     from IPython.display import clear_output
#     clear_output()
#
# Note that clear_output() will only work in jupyter. To clear the screen in other IDEs, consider:
#
#     print('\n'*100)
#
# This scrolls the previous board up out of view. Now on to the program!

# %% [markdown]
# **Step 1: Write a function that can print out a board. Set up your board as a list, where each index 1-9 corresponds with a number on a number pad, so you get a 3 by 3 board representation.**

# %%
from IPython.display import clear_output

def display_board(board):
    clear_output()
    print(board[7] + " | " + board[8] + " | " + board[9])
    print("---------")
    print(board[4] + " | " + board[5] + " | " + board[6])
    print("---------")
    print(board[1] + " | " + board[2] + " | " + board[3])

# %% [markdown]
# **TEST Step 1:** run your function on a test version of the board list, and make adjustments as necessary

# %%
test_board = ['#','1','2','3','4','5','6','7','8','9']
white_board = ['#',' ',' ',' ',' ',' ',' ',' ',' ',' ']

display_board(test_board)
# Out:
# 7 | 8 | 9
# ---------
# 4 | 5 | 6
# ---------
# 1 | 2 | 3

# %% [markdown]
# **Step 2: Write a function that can take in a player input and assign their marker as 'X' or 'O'. Think about using *while* loops to continually ask until you get a correct answer.**

# %%
def player_input():
    while True:
        P1 = input("P1 select your marker (X or O): ")
        if P1 == "X":
            P2 = "O"
            print(f"P1 has choosen {P1}. P2 is {P2}.")
            return P1, P2
        elif P1 == "O":
            P2 = "X"
            print(f"P1 has choosen {P1}. P2 is {P2}.")
            return P1, P2
        else:
            print("Please select a valid input.")

# %% [markdown]
# **TEST Step 2:** run the function to make sure it returns the desired output

# %%
P1, P2 = player_input()
# Out:
# Please select a valid input.
# Please select a valid input.
# P1 has choosen X. P2 is O.

# %% [markdown]
# **Step 3: Write a function that takes in the board list object, a marker ('X' or 'O'), and a desired position (number 1-9) and assigns it to the board.**

# %%
def place_marker(board, marker, position):
    board[position] = marker
    display_board(board)

# %% [markdown]
# **TEST Step 3:** run the place marker function using test parameters and display the modified board

# %%
test_board = ['#','1','2','3','4','5','6','7','8','9']

place_marker(test_board,'$',8)
# Out:
# 7 | $ | 9
# ---------
# 4 | 5 | 6
# ---------
# 1 | 2 | 3

# %% [markdown]
# **Step 4: Write a function that takes in a board and a mark (X or O) and then checks to see if that mark has won.**

# %%
def win_check(board, mark):
    for i in range(1, 10, 3):
        row = board[i] == board[i + 1] == board[i + 2] == mark
        if row:
           return True
    
    for i in range(1, 4, ):
        column = board[i] == board[i + 3] == board[i + 6] == mark
        if column:
            return True
    
    diagonal = board[1] == board[5] == board[9] == mark
    diagonal_inv = board[3] == board[5] == board[7] == mark
    if diagonal or diagonal_inv:
        return True

# %% [markdown]
# **TEST Step 4:** run the win_check function against our test_board - it should return True

# %%
test_board = ['#','1','2','X','4','X','6','X','8','9']
display_board(test_board)
win_check(test_board,'X')
# Out:
# X | 8 | 9
# ---------
# 4 | X | 6
# ---------
# 1 | 2 | X
# True

# %% [markdown]
# **Step 5: Write a function that uses the random module to randomly decide which player goes first. You may want to lookup random.randint() Return a string of which player went first.**

# %%
import random

def choose_first():
    flip = random.randint(0, 1)
    if flip:
        print('P1 goes first.')
        first = "P1"
        second = "P2"
        return first, second
    else:
        print('P2 goes first.')
        first = "P2"
        second = "P1"
        return first, second

# %%
choose_first()
# Out:
# P2 goes first.
# ('P2', 'P1')

# %% [markdown]
# **Step 6: Write a function that returns a boolean indicating whether a space on the board is freely available.**

# %%
def space_check(board, position):
    if board[position] == " ":
        return True
    else:
        return False

# %%
test_board = ['#',' ','2','X','4','X','6','X','8','9']
display_board(test_board)
space_check(test_board, 2)
# Out:
# X | 8 | 9
# ---------
# 4 | X | 6
# ---------
#   | 2 | X
# False

# %% [markdown]
# **Step 7: Write a function that checks if the board is full and returns a boolean value. True if full, False otherwise.**

# %%
def full_board_check(board):
    for i in range(1, len(board)):
        if space_check(board, i):
            return False
    else:
        return True

# %%
test_board = ['k','5','2','X','4','X','6','X','8','9']
display_board(test_board)
full_board_check(test_board)
# Out:
# X | 8 | 9
# ---------
# 4 | X | 6
# ---------
# 5 | 2 | X
# True

# %% [markdown]
# **Step 8: Write a function that asks for a player's next position (as a number 1-9) and then uses the function from step 6 to check if it's a free position. If it is, then return the position for later use.**

# %%
def player_choice(board):
    position = int(input("Choose a position: "))
    while 1 <= position <= 9 and space_check(board, position):
        return position
    else:
        position = int(input("Choose another position: "))

# %%
test_board = ['#','1','2','X','4','X',' ','X','8','9']
display_board(test_board)
# Out:
# X | 8 | 9
# ---------
# 4 | X |
# ---------
# 1 | 2 | X

# %%
position = player_choice(test_board)
position

# %% [markdown]
# **Step 9: Write a function that asks the player if they want to play again and returns a boolean True if they do want to play again.**

# %%
def replay():
    play_again = input("Do you want to play again? [yes/no] ")
    
    while True:
        if play_again == "yes":
            return True
        elif play_again == "no":
            return False
        else:
            play_again = input("Choose a valid option: ")

# %%
replay()
# Out:
# False

# %% [markdown]
# **Step 10: Here comes the hard part! Use while loops and the functions you've made to run the game!**

# %%
print('Welcome to Tic Tac Toe!')

game_on = True

while True:
    # Set the game up here
    board = [" "] * 10
    P1_marker, P2_marker = player_input()
    first, second = choose_first()
    
    while game_on:
        #Player 1 Turn
        position = player_choice(board)
        place_marker(board, P1_marker, position)
        
        # Player2's turn.
        position = player_choice(board)
        place_marker(board, P2_marker, position)
        pass
        break

    if not replay():
        break
# Out:
#   |   |
# ---------
#   | X | O
# ---------
#   |   |
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[300], line 22
#      19     pass
#      20     break
# ---> 22 if not replay():
#      23     break
#
# Cell In[238], line 10, in replay()
#       8     return False
#       9 else:
# ---> 10     play_again = input("Choose a valid option: ")
#
# File c:\Users\carlo\miniconda3\envs\sandbox\Lib\site-packages\ipykernel\kernelbase.py:1403, in Kernel.raw_input(self, prompt)
#    1401     msg = "raw_input was called, but this frontend does not support input requests."
#    1402     raise StdinNotImplementedError(msg)
# -> 1403 return self._input_request(
#    1404     str(prompt),
#    1405     self._get_shell_context_var(self._shell_parent_ident),
#    1406     self.get_parent("shell"),
#    1407     password=False,
#    1408 )
#
# ...

# %% [markdown]
# ## Good Job!

# %% [markdown]
# # REVISAR
#
# - Cuando escojo un lugar que no se puede y me pide que lo vuelva a ingresar, después ya no lo agarra y devuelve un error.
# - Hay un error cuando el P2 va primero, pone la marca del P1.
